# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files

# %%
image = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Sample.jpg')

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=194x259>

# %%
cv2.imwrite('output_image.jpg', image)
print("Image saved successfully as 'output_image.jpg'")
# Out:
# Image saved successfully as 'output_image.jpg'

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=194x259>

# %%
complement_image = 255 - gray_image # Complement of the grayscale image
cv2_imshow(complement_image) # Display the complemented image
# Out:
# <PIL.Image.Image image mode=L size=194x259>

# %%
#Find contours
contours, hierarchy = cv2.findContours(thresh_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# Draw contours on a copy of the original image
contour_image = image.copy()
cv2.drawContours(contour_image, contours, -1, (0, 255, 0), 2)
cv2_imshow(contour_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-fbd6d6809f59> in <cell line: 0>()
#       1 #Find contours
# ----> 2 contours, hierarchy = cv2.findContours(thresh_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#       3 # Draw contours on a copy of the original image
#       4 contour_image = image.copy()
#       5 cv2.drawContours(contour_image, contours, -1, (0, 255, 0), 2)
#
# NameError: name 'thresh_image' is not defined

# %%
# Threshold the image
ret, thresh_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
cv2_imshow(thresh_image)

# %%
# Perform edge detection using Canny
edges = cv2.Canny(gray_image, 100, 200)
cv2_imshow(edges)

# %%
# Apply Gaussian Blur
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)
cv2_imshow(blurred_image)
